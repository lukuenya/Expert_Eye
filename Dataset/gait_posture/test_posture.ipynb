# %%
# Required Libraries
import numpy as np
import pandas as pd
import os
from stabilogram.stato import Stabilogram
from descriptors import compute_all_features

# %%
# Function to load the data
def load_data(foldername):
    base_path_posture = "P:/DATA_OCT_22/Expert_Eye/Dataset/gait_posture/raw_data/{}/t0/posture/"
    posture_data_files = {
        'yf_data': "2017-09-21_08_22_12_YF.txt", # Closed eyes
        'yo_data': "2017-09-21_08_22_12_YO.txt"  # Open eyes
    }
    try:
        data_posture = {}
        for name, filename in posture_data_files.items():
            path = base_path_posture.format(foldername) + filename
            data_posture[name] = pd.read_csv(path, sep="\t")

        return data_posture
    except:
        return None

# %%
# Get the list of folders in the raw_data directory
rootDir = 'p:/DATA_OCT_22/Expert_Eye/Dataset/gait_posture/raw_data'
folder_names = [name for name in os.listdir(rootDir) if os.path.isdir(os.path.join(rootDir, name))]

# %%
def compute_posture_features(folder_names, skip_folders=[]):
    # Dataframe to store all the features
    all_features_df = pd.DataFrame()

    # Loop over all the folder names
    for foldername in folder_names:
        # If the foldername is in the skip_folders list, skip this iteration
        if foldername in skip_folders:
            print(f"Skipping folder: {foldername}")
            continue
        try:
            print(f"Processing folder: {foldername}")

            rawdata = load_data(foldername)
            # If data is not loaded or if the data frames are empty,
            # add a row of NaNs to the DataFrame for this folder
            if rawdata is None or rawdata['yf_data'].empty or rawdata['yo_data'].empty:
                print(f"Folder '{foldername}' contains empty data files. Adding NaNs to DataFrame.")
                current_df = pd.DataFrame(index=[0])
                current_df['Foldername'] = foldername
                all_features_df = pd.concat([all_features_df, current_df], ignore_index=True)
                continue

            # Length and width of Nintendo wii balance board
            length = 53.6
            width = 33.7

            # The conditions identifiers
            eye_conditions = ['YF', 'YO']

            # A dictionary to store features for each eye condition
            features_dict = {}

            for i, condition in enumerate(eye_conditions):
                eye = rawdata[f'{condition.lower()}_data']

                # Calculate the total force and COP
                eye['TotalForce'] = (eye['BottomLeftCalcul_SensorsKG'] +
                    eye['BottomRightCalcul_SensorsKG'] +
                    eye['TopLeftCalcul_SensorsKG'] +
                    eye['TopRightCalcul_SensorsKG'])

                # Calculate COP_X and COP_Y
                eye['COP_X'] = ((eye['BottomLeftCalcul_SensorsKG'] +
                    eye['TopLeftCalcul_SensorsKG']) * width / 2 -
                    (eye['BottomRightCalcul_SensorsKG'] +
                    eye['TopRightCalcul_SensorsKG']) * width / 2) / eye['TotalForce']

                eye['COP_Y'] = ((eye['BottomLeftCalcul_SensorsKG'] +
                    eye['BottomRightCalcul_SensorsKG']) * length / 2 -
                    (eye['TopLeftCalcul_SensorsKG'] +
                    eye['TopRightCalcul_SensorsKG']) * length / 2) / eye['TotalForce']
                
                # Calculate the mean value of COP_X and COP_Y
                mean_COP_X = eye['COP_X'].mean()
                mean_COP_Y = eye['COP_Y'].mean()

                # Subtract the mean from each measurement to center the trajectories
                eye['COP_X_centered'] = eye['COP_X'] - mean_COP_X
                eye['COP_Y_centered'] = eye['COP_Y'] - mean_COP_Y

                time = eye['TIMESTAMP'].to_numpy()
                X = eye['COP_X_centered'].to_numpy()
                Y = eye['COP_Y_centered'].to_numpy()

                data = np.array([time, X, Y]).T

                # Verif if NaN data
                valid_index = (np.sum(np.isnan(data),axis=1) == 0)

                if np.sum(valid_index) != len(data):
                    raise ValueError("Clean NaN values first")

                stato = Stabilogram()
                stato.from_array(array=data)

                sway_density_radius = 0.3 # 3 mm

                params_dic = {"sway_density_radius": sway_density_radius}

                features = compute_all_features(stato, params_dic=params_dic)
                
                # Add the condition identifier to each key in the features dictionary
                features = {f'{k}_{condition}': v for k, v in features.items()}

                # Add the condition identifier to each key in the features dictionary
                features = {f'{k}_{condition}': v for k, v in features.items()}

                # Store the features for this condition in the features_dict
                features_dict[condition] = features

            # Combine features from all conditions into a single DataFrame
            all_features = pd.DataFrame({**features_dict['YF'], **features_dict['YO']}, index=[0])
            
            # Add the 'Foldername' to the all_features dataframe
            all_features['Foldername'] = foldername

            # Append the all_features dataframe to all_features_df
            all_features_df = pd.concat([all_features_df, all_features], ignore_index=True)

        except Exception as e:
            print(f"An error occurred while processing folder: {foldername}")
            print(f"Error: {e}")
            # optional: if you want to stop at the first error
            break

    # return the all_features_df
    return all_features_df

# %%
skip_folders = ['FRA005GMS', 'FRA008TJL', 'FRA010DMA', 'HUC001HMR', 'LEG007TGL', 'LEG018BPC', 'LEG027HJO', 'LEG034KLG', 'LEG042HJO', 'LEG047VSI', 'LEG048VHI', 'LEG049FAL', 'LEG050LMN']
posture_features = compute_posture_features(folder_names, skip_folders)
# Out:
# Processing folder: DUP002BME
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891040>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891040>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891BE0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891BE0>
# Processing folder: FRA001AMA
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F970>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F970>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891250>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891250>
# Processing folder: FRA002CTI
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F0A0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F0A0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891C40>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891C40>
# Processing folder: FRA003BMG
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F3D0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F3D0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58914C0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58914C0>
# Processing folder: FRA004LHN
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FB50>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FB50>
# <stabilogram.stato.Stabilogram object at 0x0000016E9FDCA5B0>
# <stabilogram.stato.Stabilogram object at 0x0000016E9FDCA5B0>
# Skipping folder: FRA005GMS
# Processing folder: FRA006PJA
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F160>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F160>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891910>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891910>
# Processing folder: FRA007TTM
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F640>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F640>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58918B0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58918B0>
# Skipping folder: FRA008TJL
# Processing folder: FRA009RMI
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FA90>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FA90>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891910>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891910>
# Skipping folder: FRA010DMA
# Processing folder: FRA011VJR
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FBE0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FBE0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58918E0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58918E0>
# Processing folder: FRA012BJN
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FAF0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FAF0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891550>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891550>
# Processing folder: FRA013PMD
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F3A0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F3A0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58915E0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58915E0>
# Processing folder: FRA014GJ
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F460>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F460>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891B20>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891B20>
# Processing folder: FRA015FMJ
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F250>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F250>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891B50>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891B50>
# Processing folder: FRA016GJ
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FA90>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FA90>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58911F0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58911F0>
# Processing folder: FRA018ACV
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F580>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F580>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB8E0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB8E0>
# Processing folder: FRA019AMA
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F430>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F430>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891040>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891040>
# Processing folder: FRA020THJ
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F100>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F100>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB370>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB370>
# Processing folder: FRA021LPA
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F850>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F850>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58914F0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58914F0>
# Processing folder: FRA022RMT
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FA60>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FA60>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB6A0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB6A0>
# Processing folder: FRA023CMC
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F610>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F610>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EBD30>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EBD30>
# Processing folder: FRA025HJM
# <stabilogram.stato.Stabilogram object at 0x0000016EA58913D0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58913D0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F550>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F550>
# Processing folder: FRA026RAL
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891460>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891460>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F340>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F340>
# Processing folder: FRA027MST
# <stabilogram.stato.Stabilogram object at 0x0000016EA4E53BB0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA4E53BB0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F700>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F700>
# Processing folder: FRA028MJC
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891160>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891160>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F130>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F130>
# Processing folder: FRA029SCM
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891E80>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891E80>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FB50>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FB50>
# Processing folder: FRA030DHJ
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891070>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891070>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F070>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F070>
# Processing folder: FRA031AMJ
# <stabilogram.stato.Stabilogram object at 0x0000016EA58914C0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58914C0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F970>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F970>
# Processing folder: FRA032AEJ
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EBD30>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EBD30>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F100>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F100>
# Processing folder: FRA033SMC
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB0A0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB0A0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F250>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F250>
# Processing folder: FRA034GLM
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EBAC0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EBAC0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FFA0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FFA0>
# Processing folder: FRA035GMD
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB0A0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB0A0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F910>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F910>
# Processing folder: FRA036GMM
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891700>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891700>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F5B0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F5B0>
# Processing folder: FRA038HLJ
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891B80>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891B80>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F610>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F610>
# Processing folder: FRA039CVM
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EBF10>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EBF10>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F580>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F580>
# Processing folder: FRA040GTG
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891040>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891040>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCDC0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCDC0>
# Processing folder: FRA041HJA
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EBDF0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EBDF0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCCD0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCCD0>
# Processing folder: FRA043TMC
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891820>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891820>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F580>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F580>
# Processing folder: FRA044HMC
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB430>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB430>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DC130>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DC130>
# Processing folder: FRA045AJN
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891BE0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891BE0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F460>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F460>
# Processing folder: FRA046TJ
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB790>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB790>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCFD0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCFD0>
# Processing folder: FRA048HAG
# <stabilogram.stato.Stabilogram object at 0x0000016EA58916A0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58916A0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F100>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F100>
# Processing folder: FRA050FMA
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB970>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB970>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DC0D0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DC0D0>
# Processing folder: FRA053DL
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891AC0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891AC0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCF10>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCF10>
# Processing folder: FRA054CMJ
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891F40>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891F40>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EBC10>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EBC10>
# Skipping folder: HUC001HMR
# Processing folder: LEG001DPA
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FB50>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584FB50>
# <stabilogram.stato.Stabilogram object at 0x0000016EA43F7160>
# <stabilogram.stato.Stabilogram object at 0x0000016EA43F7160>
# Processing folder: LEG002SPA
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F5B0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA584F5B0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891F40>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891F40>
# Processing folder: LEG003CMA
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB430>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EB430>
# <stabilogram.stato.Stabilogram object at 0x0000016E9FDCACD0>
# <stabilogram.stato.Stabilogram object at 0x0000016E9FDCACD0>
# Processing folder: LEG005AMA
# <stabilogram.stato.Stabilogram object at 0x0000016EA58914C0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58914C0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DC0D0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DC0D0>
# Processing folder: LEG006BJO
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891670>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891670>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DC0D0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DC0D0>
# Skipping folder: LEG007TGL
# Processing folder: LEG008BMY
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DC4F0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DC4F0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891880>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891880>
# Processing folder: LEG009BMT
# <stabilogram.stato.Stabilogram object at 0x0000016E9FC889A0>
# <stabilogram.stato.Stabilogram object at 0x0000016E9FC889A0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCCD0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCCD0>
# Processing folder: LEG010MIC
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891A60>
# <stabilogram.stato.Stabilogram object at 0x0000016EA5891A60>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCD00>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCD00>
# Processing folder: LEG011DMA
# <stabilogram.stato.Stabilogram object at 0x0000016EA58915B0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58915B0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCCD0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCCD0>
# Processing folder: LEG012JYV
# <stabilogram.stato.Stabilogram object at 0x0000016E9FDCA3A0>
# <stabilogram.stato.Stabilogram object at 0x0000016E9FDCA3A0>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DC640>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DC640>
# Processing folder: LEG013DJM
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EBA30>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58EBA30>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCD00>
# <stabilogram.stato.Stabilogram object at 0x0000016EA58DCD00>
# Processing folder: LEG014JFR
# Folder 'LEG014JFR' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG015ANN
# Folder 'LEG015ANN' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG016DIR
# Folder 'LEG016DIR' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG017DDE
# Folder 'LEG017DDE' contains empty data files. Adding NaNs to DataFrame.
# Skipping folder: LEG018BPC
# Processing folder: LEG019FMA
# Folder 'LEG019FMA' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG020EOD
# Folder 'LEG020EOD' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG021BCH
# Folder 'LEG021BCH' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG022DJP
# Folder 'LEG022DJP' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG023HCR
# Folder 'LEG023HCR' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG024GCF
# Folder 'LEG024GCF' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG025HJF
# Folder 'LEG025HJF' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG026BCA
# Folder 'LEG026BCA' contains empty data files. Adding NaNs to DataFrame.
# Skipping folder: LEG027HJO
# Processing folder: LEG028DJO
# Folder 'LEG028DJO' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG029KPJ
# Folder 'LEG029KPJ' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG030KAN
# Folder 'LEG030KAN' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG032HMP
# Folder 'LEG032HMP' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG033MML
# Folder 'LEG033MML' contains empty data files. Adding NaNs to DataFrame.
# Skipping folder: LEG034KLG
# Processing folder: LEG035PCJ
# Folder 'LEG035PCJ' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG036MJL
# Folder 'LEG036MJL' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG037MMN
# Folder 'LEG037MMN' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG038PVA
# Folder 'LEG038PVA' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG039PRE
# Folder 'LEG039PRE' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG040PAB
# Folder 'LEG040PAB' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG041DUS
# Folder 'LEG041DUS' contains empty data files. Adding NaNs to DataFrame.
# Skipping folder: LEG042HJO
# Processing folder: LEG043VJC
# Folder 'LEG043VJC' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG044TJJ
# Folder 'LEG044TJJ' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG045BGU
# Folder 'LEG045BGU' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: LEG046BBE
# Folder 'LEG046BBE' contains empty data files. Adding NaNs to DataFrame.
# Skipping folder: LEG047VSI
# Skipping folder: LEG048VHI
# Skipping folder: LEG049FAL
# Skipping folder: LEG050LMN
# Processing folder: MOU001NYA
# Folder 'MOU001NYA' contains empty data files. Adding NaNs to DataFrame.
# Processing folder: MOU002NJ
# Folder 'MOU002NJ' contains empty data files. Adding NaNs to DataFrame.

# %%
posture_features.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 posture_features.head()
#
# NameError: name 'posture_features' is not defined

# %%
# Save the dataframe to an Excel file
#all_features_df.to_excel('all_features.xlsx')
